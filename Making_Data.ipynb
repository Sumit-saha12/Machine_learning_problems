# %% [markdown]
# ## Import Library

# %%
from sklearn.datasets import make_regression, make_classification, make_blobs, make_circles, make_moons
import matplotlib.pyplot as plt

# %% [markdown]
# ## Make Regression Data

# %%
x,y = make_regression(n_features=1,noise = 6,n_samples = 1000, random_state=5)

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Make Classificaition Data

# %%
x,y = make_classification(n_classes=2,n_features=5,n_samples=10000,random_state=0)

# %%
plt.scatter(x[:,0],x[:,1],c=y)
# plt.legend()
# plt.show()

# %% [markdown]
# ## Make Blob Data

# %%
x,y = make_blobs(n_features=5,centers=6,n_samples=10000,random_state=3)
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %% [markdown]
# ## Make Circle Data

# %%
x,y = make_circles(noise=0.02,n_samples=10000, random_state=0)
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %% [markdown]
# ## Make Moon Data

# %%
x,y =make_moons(noise = 0.005,random_state=1)
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()
