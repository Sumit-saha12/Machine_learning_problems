# %%
from sklearn.datasets import make_regression, make_classification, make_blobs
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression

# %% [markdown]
# ## Linear Regresssion

# %%
x,y = make_regression(n_samples=10000,noise=10,n_features=1,random_state=1)

# %%
plt.scatter(x,y,c=y)

# %%
x=x.reshape(-1,1)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9868322233546433

# %%
pred=model.predict(x)

# %%
plt.scatter(x,y,c=y)
plt.plot(x,pred,color='red')

# %% [markdown]
# ## Logistic Regression

# %%
data = pd.read_csv('job.csv')
data.head(5)
# Out:
#    Years  result
# 0     22       0
# 1     25       0
# 2     47       1
# 3     52       0
# 4     46       1

# %%
X=data[['Years']]
Y=data.result

# %%
plt.scatter(X,Y,c=Y)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
model = LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.8333333333333334

# %%
pred = model.predict(X)

# %%
plt.scatter(X,Y,c=Y)
sns.regplot(x=X,y=pred,logistic=True,ci=None)
# Out:
# /Users/sumitsaha/anaconda3/lib/python3.11/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /Users/sumitsaha/anaconda3/lib/python3.11/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /Users/sumitsaha/anaconda3/lib/python3.11/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# <Axes: xlabel='Years'>
