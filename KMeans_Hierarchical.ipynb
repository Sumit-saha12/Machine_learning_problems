# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.datasets import make_blobs,make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
x,y = make_blobs(n_features=40,centers=3,n_samples=10000,random_state=1)

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %% [markdown]
# ## KMeans Clustering

# %%
model=KMeans(n_clusters=3)

# %%
model.fit(x)
# Out:
# /Users/sumitsaha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
pred=model.predict(x)

# %%
plt.scatter(x[:,0],x[:,1],c=pred)

# %%
x,y=make_moons(noise=0.03,n_samples=5000,random_state=1)
plt.scatter(x[:,0],x[:,1],c=y)

# %%
model=KMeans(n_clusters=2)
model.fit(x)
# Out:
# /Users/sumitsaha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=2)

# %%
pred=model.predict(x)
plt.scatter(x[:,0],x[:,1],c=pred)

# %% [markdown]
# ## Agglomerative Clustering

# %%
model = AgglomerativeClustering(linkage='single')
model.fit(x)
# Out:
# AgglomerativeClustering(linkage='single')

# %%
model.labels_
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
plt.scatter(x[:,0],x[:,1],c=model.labels_)
