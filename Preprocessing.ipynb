# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, Binarizer
import pandas as pd

# %%
a=np.array([1,5,90,7,5,98000,78,6])
a
# Out:
# array([    1,     5,    90,     7,     5, 98000,    78,     6])

# %%
b=pd.DataFrame(a)
b.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
min = a.min()
max = a.max()

# %%
# sum = 0
# for i in range(a):
#     a[i] =((a[i]-min)/(max-min))
# a

# %%
a=a.reshape(-1,1)

# %%
g = MinMaxScaler()

# %%
g.fit_transform(a)
# Out:
# array([[0.00000000e+00],
#        [4.08167430e-05],
#        [9.08172532e-04],
#        [6.12251145e-05],
#        [4.08167430e-05],
#        [1.00000000e+00],
#        [7.85722303e-04],
#        [5.10209288e-05]])

# %%
g=pd.DataFrame(a)
g.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
c = StandardScaler()
c.fit_transform(a)
# Out:
# array([[-0.37877993],
#        [-0.37865648],
#        [-0.37603314],
#        [-0.37859475],
#        [-0.37865648],
#        [ 2.64574989],
#        [-0.37640349],
#        [-0.37862562]])

# %%
e = RobustScaler()
e.fit_transform(a)
# Out:
# array([[-7.23684211e-02],
#        [-1.97368421e-02],
#        [ 1.09868421e+00],
#        [ 6.57894737e-03],
#        [-1.97368421e-02],
#        [ 1.28938816e+03],
#        [ 9.40789474e-01],
#        [-6.57894737e-03]])

# %%
f = Binarizer(threshold=10)
f.fit_transform(a)
# Out:
# array([[0],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [1],
#        [0]])
